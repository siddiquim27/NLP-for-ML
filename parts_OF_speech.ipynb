# %% [markdown]
# Parts of speech

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
## speech of dr. apj abdul kalam sir

paragraph = """

I am delighted to participate in the launching of computerization of courts
organized by Supreme Court of India. My greetings to Honorable Chief Justice
 of India, Honorable Justices of Supreme Court, Members of the Bar, administrative
 officers, staff and the members of E-Committee. In the last 5 years, I would have
 interacted with many High Courts and the Supreme Court for more than 15 times on various occasions.
  I am very happy that substantial progress has been made in the courts to improve the justice delivery system
  such as specific efforts for bringing down the pendency of cases, fast settlement of cases especially pertaining
   to women and children and the use of technology for handling certain special cases. I also see the
    websites of various courts and I am convinced that the courts are constantly improving the systems and
    procedures using ICT tools and are making timely information available to people thus ensuring courts
    are friendly to citizens. I appreciate the ?e-courts? efforts taken by the Supreme Court of India in
    three phases as a mission mode project under the National e-Governance Plan (NeGEP). It is planned to
     provide necessary infrastructure and concentrate on capacity building, judicial process from filing to
      execution and finally making the information available online between the courts, prosecuting and investigating
      agencies, prisons, land records and registration offices thereby accelerating disposal of civil and criminal cases.
      While you are concentrating on the computerization of courts for transforming them into e-Courts in three phases,
      I would like to focus on creating the e-judiciary by establishing the Judicial e-Governance grid from the district
       courts to the Apex Court, thereby creating a vertical e-Governance grid for covering the whole judicial system of
        the country. This Grid will ensure seamless flow of information and case objects across the inter-departmental barrier
        in a G2G mode across the vertical grid. This will be supported by the other horizontal e-Governance grid from the State
        and Central Government related to the particular case object which will facilitate the case objects to flow across
         judicial process at various stages ensuring the speed, transparency and inter-operability thereby eliminating duplicity
          and ensuring the speedy justice. For an effective e-Judiciary, national identity card has to be the primary
           linking all the e-Governance activities.
"""

# %%
from nltk.corpus import stopwords
sentence = nltk.sent_tokenize(paragraph)

# %%
# we will find pos tag
for i in range(len(sentence)):
    words = nltk.word_tokenize(sentence[i])
    words = [word for word in words if word not in set(stopwords.words('english'))]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('I', 'PRP'), ('delighted', 'VBD'), ('participate', 'JJ'), ('launching', 'NN'), ('computerization', 'NN'), ('courts', 'NNS'), ('organized', 'VBN'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('India', 'NNP'), ('.', '.')]
# [('My', 'PRP$'), ('greetings', 'NNS'), ('Honorable', 'NNP'), ('Chief', 'NNP'), ('Justice', 'NNP'), ('India', 'NNP'), (',', ','), ('Honorable', 'NNP'), ('Justices', 'NNP'), ('Supreme', 'NNP'), ('Court', 'NNP'), (',', ','), ('Members', 'NNP'), ('Bar', 'NNP'), (',', ','), ('administrative', 'JJ'), ('officers', 'NNS'), (',', ','), ('staff', 'NN'), ('members', 'NNS'), ('E-Committee', 'NNP'), ('.', '.')]
# [('In', 'IN'), ('last', 'JJ'), ('5', 'CD'), ('years', 'NNS'), (',', ','), ('I', 'PRP'), ('would', 'MD'), ('interacted', 'VB'), ('many', 'JJ'), ('High', 'NNP'), ('Courts', 'NNP'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('15', 'CD'), ('times', 'NNS'), ('various', 'JJ'), ('occasions', 'NNS'), ('.', '.')]
# [('I', 'PRP'), ('happy', 'JJ'), ('substantial', 'JJ'), ('progress', 'NN'), ('made', 'VBD'), ('courts', 'NNS'), ('improve', 'VB'), ('justice', 'NN'), ('delivery', 'NN'), ('system', 'NN'), ('specific', 'JJ'), ('efforts', 'NNS'), ('bringing', 'VBG'), ('pendency', 'NN'), ('cases', 'NNS'), (',', ','), ('fast', 'RB'), ('settlement', 'NN'), ('cases', 'NNS'), ('especially', 'RB'), ('pertaining', 'VBG'), ('women', 'NNS'), ('children', 'NNS'), ('use', 'VBP'), ('technology', 'NN'), ('handling', 'VBG'), ('certain', 'JJ'), ('special', 'JJ'), ('cases', 'NNS'), ('.', '.')]
# [('I', 'PRP'), ('also', 'RB'), ('see', 'VBP'), ('websites', 'VBZ'), ('various', 'JJ'), ('courts', 'NNS'), ('I', 'PRP'), ('convinced', 'VBD'), ('courts', 'NNS'), ('constantly', 'RB'), ('improving', 'VBG'), ('systems', 'NNS'), ('procedures', 'NNS'), ('using', 'VBG'), ('ICT', 'NNP'), ('tools', 'NNS'), ('making', 'VBG'), ('timely', 'JJ'), ('information', 'NN'), ('available', 'JJ'), ('people', 'NNS'), ('thus', 'RB'), ('ensuring', 'VBG'), ('courts', 'NNS'), ('friendly', 'RB'), ('citizens', 'NNS'), ('.', '.')]
# [('I', 'PRP'), ('appreciate', 'VBP'), ('?', '.'), ('e-courts', 'NNS'), ('?', '.')]
# [('efforts', 'NNS'), ('taken', 'VBN'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('India', 'NNP'), ('three', 'CD'), ('phases', 'NNS'), ('mission', 'NN'), ('mode', 'NN'), ('project', 'VBP'), ('National', 'NNP'), ('e-Governance', 'NN'), ('Plan', 'NN'), ('(', '('), ('NeGEP', 'NNP'), (')', ')'), ('.', '.')]
# [('It', 'PRP'), ('planned', 'VBD'), ('provide', 'RB'), ('necessary', 'JJ'), ('infrastructure', 'NN'), ('concentrate', 'NN'), ('capacity', 'NN'), ('building', 'NN'), (',', ','), ('judicial', 'JJ'), ('process', 'NN'), ('filing', 'NN'), ('execution', 'NN'), ('finally', 'RB'), ('making', 'VBG'), ('information', 'NN'), ('available', 'JJ'), ('online', 'NN'), ('courts', 'NNS'), (',', ','), ('prosecuting', 'VBG'), ('investigating', 'NN'), ('agencies', 'NNS'), (',', ','), ('prisons', 'NNS'), (',', ','), ('land', 'NN'), ('records', 'NNS'), ('registration', 'NN'), ('offices', 'NNS'), ('thereby', 'RB'), ('accelerating', 'VBG'), ('disposal', 'NN'), ('civil', 'JJ'), ('criminal', 'JJ'), ('cases', 'NNS'), ('.', '.')]
# [('While', 'IN'), ('concentrating', 'VBG'), ('computerization', 'NN'), ('courts', 'NNS'), ('transforming', 'VBG'), ('e-Courts', 'NNS'), ('three', 'CD'), ('phases', 'NNS'), (',', ','), ('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('focus', 'VB'), ('creating', 'VBG'), ('e-judiciary', 'JJ'), ('establishing', 'VBG'), ('Judicial', 'JJ'), ('e-Governance', 'NN'), ('grid', 'JJ'), ('district', 'NN'), ('courts', 'NNS'), ('Apex', 'NNP'), ('Court', 'NNP'), (',', ','), ('thereby', 'RB'), ('creating', 'VBG'), ('vertical', 'JJ'), ('e-Governance', 'NN'), ('grid', 'NN'), ('covering', 'VBG'), ('whole', 'JJ'), ('judicial', 'JJ'), ('system', 'NN'), ('country', 'NN'), ('.', '.')]
# [('This', 'DT'), ('Grid', 'NNP'), ('ensure', 'VB'), ('seamless', 'NN'), ('flow', 'NN'), ('information', 'NN'), ('case', 'NN'), ('objects', 'VBZ'), ('across', 'IN'), ('inter-departmental', 'JJ'), ('barrier', 'NN'), ('G2G', 'NNP'), ('mode', 'NN'), ('across', 'IN'), ('vertical', 'JJ'), ('grid', 'NN'), ('.', '.')]
# [('This', 'DT'), ('supported', 'VBD'), ('horizontal', 'JJ'), ('e-Governance', 'NN'), ('grid', 'NN'), ('State', 'NNP'), ('Central', 'NNP'), ('Government', 'NNP'), ('related', 'VBD'), ('particular', 'JJ'), ('case', 'NN'), ('object', 'JJ'), ('facilitate', 'NN'), ('case', 'NN'), ('objects', 'VBZ'), ('flow', 'JJ'), ('across', 'IN'), ('judicial', 'JJ'), ('process', 'NN'), ('various', 'JJ'), ('stages', 'NNS'), ('ensuring', 'VBG'), ('speed', 'NN'), (',', ','), ('transparency', 'NN'), ('inter-operability', 'NN'), ('thereby', 'NN'), ('eliminating', 'VBG'), ('duplicity', 'NN'), ('ensuring', 'VBG'), ('speedy', 'JJ'), ('justice', 'NN'), ('.', '.')]
# [('For', 'IN'), ('effective', 'JJ'), ('e-Judiciary', 'JJ'), (',', ','), ('national', 'JJ'), ('identity', 'NN'), ('card', 'NN'), ('primary', 'JJ'), ('linking', 'VBG'), ('e-Governance', 'NN'), ('activities', 'NNS'), ('.', '.')]

# %%
import nltk
from nltk import word_tokenize
sentence = "Taj Mahal is a beautiful monument"
tokens = word_tokenize(sentence)

# Wrap the tokenized sentence in a list
pos_tags = nltk.pos_tag_sents([tokens])
print(pos_tags)
# Out:
# [[('Taj', 'NNP'), ('Mahal', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('monument', 'NN')]]
